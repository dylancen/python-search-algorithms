# %% [markdown]
# How to import the map from an area using osmnx
#
# reference websites:
#
# https://deepnote.com/@siew-sook-yan/Python-Retrieving-OpenStreetMap-data-with-OSMNX-NIFhR_zARQm2jYqcctP5hg
#
# https://towardsdatascience.com/retrieving-openstreetmap-data-in-python-1777a4be45bb (incorrect extraction of buildings)

# %%
# !apt-get -qq install -y libspatialindex-dev && pip install -q -U osmnx 
import osmnx as ox 
ox.config(use_cache=True, log_console=True)
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# Matplotlib is building the font cache; this may take a moment.

# %%
place = "Hempstead, NY, United States"
graph = ox.graph_from_place(place, network_type='drive')
# Out:
# C:\Users\dylan\anaconda3\envs\ox\lib\site-packages\osmnx\geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
nodes, streets = ox.graph_to_gdfs(graph)

# %%
print(streets.shape)
# Out:
# (56876, 13)

# %%
streets.head()
# Out:
#                             osmid  oneway                                name  \
# u        v         key
# 42792459 261382632 0    224675439   False                         Elmont Road
#          261447777 0    461287020   False  Hook Creek Boulevard - Elmont Road
# 42823046 261344530 0     24125681   False                     Garfield Avenue
#          261442903 0    420339317    True                    Jericho Turnpike
# 42844989 261409128 0     24123978   False                         95th Avenue
#
#                             highway  length  \
# u        v         key
# 42792459 261382632 0      secondary  21.273
#          261447777 0       tertiary  67.048
# 42823046 261344530 0    residential  88.249
#          261442903 0        primary  74.096
# 42844989 261409128 0    residential  75.971
#
#                                                                  geometry  \
# u        v         key
# 42792459 261382632 0    LINESTRING (-73.72583 40.68326, -73.72573 40.6...
# ...

# %%
print(nodes.shape)
# Out:
# (20571, 6)

# %%
nodes.head()
# Out:
#                    y          x  ...  ref                    geometry
# osmid                            ...
# 42792459   40.683256 -73.725829  ...  NaN  POINT (-73.72583 40.68326)
# 42823046   40.727783 -73.707594  ...  NaN  POINT (-73.70759 40.72778)
# 42844989   40.720478 -73.729678  ...  NaN  POINT (-73.72968 40.72048)
# 42929218   40.611981 -73.749079  ...  NaN  POINT (-73.74908 40.61198)
# 261339686  40.682585 -73.709088  ...  NaN  POINT (-73.70909 40.68259)
#
# [5 rows x 6 columns]

# %%
nodes.columns
# Out:
# Index(['y', 'x', 'highway', 'street_count', 'ref', 'geometry'], dtype='object')

# %%
area = ox.geocode_to_gdf(place)
type(area)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(area)
# Out:
#                                             geometry  ...  importance
# 0  POLYGON ((-73.76702 40.62548, -73.76695 40.624...  ...    0.764616
#
# [1 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.plot(area)

# %%
buildings = ox.geometries_from_place(place, tags={'building':True}) # point=point, distance=dist)
# Out:
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):

# %%
len(buildings)
# Out:
# 177454

# %%
buildings.columns
# Out:
# Index(['geometry', 'addr:city', 'addr:housename', 'addr:housenumber',
#        'addr:postcode', 'addr:state', 'addr:street', 'amenity', 'building',
#        'denomination',
#        ...
#        'building:levels:underground', 'operator:short', 'content',
#        'generator:place', 'opening_hours:covid19', 'ways', 'beds', 'bus',
#        'passenger_information_display', 'public_transport'],
#       dtype='object', length=189)

# %%
buildings.head()
# Out:
#                                           geometry  ... public_transport
# element_type osmid                                  ...
# node         357613273  POINT (-73.72243 40.68400)  ...              NaN
#              368043133  POINT (-73.65441 40.71731)  ...              NaN
#              368043172  POINT (-73.60423 40.71370)  ...              NaN
#              368045071  POINT (-73.62664 40.68685)  ...              NaN
#              368045538  POINT (-73.58263 40.70093)  ...              NaN
#
# [5 rows x 189 columns]

# %%
# Retrieve restaurants
restaurants = ox.geometries_from_place(place, 
                                  tags={"amenity": "restaurants"}
                                 )

# %%
len(restaurants)
# Out:
# 421

# %%
universities = ox.geometries_from_place(place, tags={"building": "university"})

# %%
universities
# Out:
#                         addr:state  ...          type
# element_type osmid                  ...
# node         368043133          NY  ...           NaN
#              368054881          NY  ...           NaN
#              368054884          NY  ...           NaN
#              368054892          NY  ...           NaN
#              368054903          NY  ...           NaN
#              368054921          NY  ...           NaN
#              368054924          NY  ...           NaN
#              368054931          NY  ...           NaN
#              3513692394        NaN  ...           NaN
#              3513692408        NaN  ...           NaN
#              3513692411        NaN  ...           NaN
# way          228609846          NY  ...           NaN
#              404414592          NY  ...           NaN
#              589561070         NaN  ...           NaN
#              589561071          NY  ...           NaN
#              589561072         NaN  ...           NaN
# ...
